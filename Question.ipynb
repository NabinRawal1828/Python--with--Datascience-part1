# %% [markdown]
# # Question 1

# %%
Imagine you're working on a customer management system, and you have the first name and last name of a customer stored as
seperate variables.You're developing a customer management system for a retail store. In your database, you have the first
name and last name of a customer stored as a seperate variables:first_name = "Nabin" and last_name = "Doe".How would you concentate 
these strings to form the full name "Nabin Rawal" for the customer's profile.

# %%
first_name = "Nabin"
last_name = "Rawal"
full_name = first_name + " "+ last_name
print(full_name)
# Out:
# Nabin Rawal

# %% [markdown]
# # Question 2

# %%
You have a variable X with the value of 5.How would you reassign X to have the value 10?

# %%
x = 5
print(x)
x = 10
print(x)
# Out:
# 5
# 10

# %%
print(x)
# Out:
# 10
