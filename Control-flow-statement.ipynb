# %% [markdown]
# # Control-flow statement

# %%
Control statements in Python are used to control the flow of a program.

# %% [markdown]
# # if statement

# %%
If statement is a control statement used to check a condition and execute code only if the condition is true.

# %%
n = 20
if(n > 10):
    print("20 is greater than 10")
else:
    print("20 is less than 10")
# Out:
# 20 is greater than 10

# %%
Develop a temperature converter in python for a cold storage that converts temperatures between celsius and Frahenheit scales.
The program should take a temperatrure value and a unit  (C or F) as input. If the temperature is less than 15 degree celsius,
inform the user that the temperature is not convenient.If the temperature is between 24 to 28 degree Celsius, Inform the user that the temperature 
is convient.

# %%
temp = float(input("Enter the temperature:"))
if (temp < 15):
    print("The temperature is not convient ")
if(24<temp<28):
    print("Temperature is convient")
# Out:
# Enter the temperature: 26
# Temperature is convient

# %% [markdown]
# # if else statement

# %%
 If–else statement executes one block if the condition is true, otherwise it executes another block.

# %%
Write a program to check whether a person is eligible for voting or not

# %%
age = int(input("Enter your age for voting:"))
if(age>18):
    print("You are eligible for vote")
else:
    print("you are not eligible for vote")
# Out:
# Enter your age for voting: 12
# you are not eligible for vote

# %%
You are tasked with developing a python program to manage employee salaries for a company. your program should calculate 
the net salarly of each employee based on their base salarly, deductions, and bonuses.Additionally,employees who have been with
the company for more than 5 years, 8% of salarly.Deduction of tax will be 12%

write a python script that prompts the user to input the following information for each employee:
Basic salarly
Years of service

After calculating the net salarly, the program should print a summary for each employee including their base salarly,
deductions, bounses, loyality bonus (if applicable), and net salarly

# %%
Base_salarly = float(input("Enter your base salarly:"))
years_of_services = int(input("Enter your years of services:"))
if years_of_services > 5:
    total_salarly = Base_salarly + (0.08*Base_salarly)-(0.12*Base_salarly)
    print("Your net salarly will be :",total_salarly)
else:
    net_salarly = Base_salarly -(0.12*Base_salarly)
    print("Your net salarly is:",net_salarly)
# Out:
# Enter your base salarly: 50000
# Enter your years of services: 3
# Your net salarly is: 44000.0

# %% [markdown]
# # if elif else

# %%
if is a conditional statement used to check a condition. If the condition is true, the block of code inside if is executed.

# %%
write a python program that prompt the user to input a ipl teams and displays their famous players.

# %%
a = input("Enter the ipl teams :")
if a == "chennai":
    print("ms-dhoni")
elif a == "RCB":
    print("virat kholi")
elif a=="Mumbai-indian":
    print("Rohit sharma")
elif a == "SRH":
    print("Abishek sharma")
else:
   print("wrong information")
# Out:
# Enter the ipl teams : chennai
# ms-dhoni
