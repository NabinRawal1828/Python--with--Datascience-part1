# %% [markdown]
# # Operators in python

# %% [markdown]
# # Arithmetic opeartor

# %%
a = 3
b = 2
print(a+b)
# Out:
# 5

# %%
x = 1.5
y = 3.4
print(x+y)
# Out:
# 4.9

# %%
m = "hello"
n = "world"
print(m+" "+n)
# Out:
# hello world

# %%
x1 = 3+5j
y1 = 4+8j
print(x1+y1)
# Out:
# (7+13j)

# %% [markdown]
# # subtractor opeartor

# %%
num1 = 9
num2 = 4
print(num1-num2)
# Out:
# 5

# %%
## a1 = 5.39
a2 = 1.34
print(a1-a2)
# Out:
# 4.05

# %%
c1 = 5+4j
c2 = 3+2j
print(c1-c2)
# Out:
# (2+2j)

# %% [markdown]
# # Multiplication operator

# %%
n = 3
m = 5
print(n*m)
# Out:
# 15

# %%
p1 = 2.6
p2 = 4.5
print(p1*p2)
# Out:
# 11.700000000000001

# %%
s1 = "Nabin"
s2 = "Rawal"
print(s1*s2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 s1 = "Nabin"
#       2 s2 = "Rawal"
# ----> 3 print(s1*s2)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
comp1 = 2+5j
comp2 = 5+9j
print(comp1*comp2)
# Out:
# (-35+43j)

# %% [markdown]
# # Division operator

# %%
a = 15
b = 3
print(a/b)
# Out:
# 5.0

# %%
a1 = 23364565.6565
b1 = 656576767.4545
print(a1/b1)
# Out:
# 0.03558542856623257

# %%
comp1 = 4+3j
comp2 = 2+2j
print(comp1/comp2)
# Out:
# (1.75-0.25j)

# %% [markdown]
# # Modulous operator

# %%
print(12%4)
# Out:
# 0

# %%
print(20%3)
# Out:
# 2

# %%
a1 = 46546545.7879
b1 = 767687876.787
print(a1%b1)
# Out:
# 46546545.7879

# %%
b1 = 3+5j
b2 = 6+8j
print(b1%b2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 3
#       1 b1 = 3+5j
#       2 b2 = 6+8j
# ----> 3 print(b1%b2)
#
# TypeError: unsupported operand type(s) for %: 'complex' and 'complex'

# %% [markdown]
# # Exponent operator

# %%
print(2**4)
# Out:
# 16

# %%
w = 45
h = 5.6
v = h**2
print(w/v)
# Out:
# 1.4349489795918369

# %% [markdown]
# # Boolean opeartor

# %%
a = True 
print(type(a))
# Out:
# <class 'bool'>

# %%
b = False
print(type(b))
# Out:
# <class 'bool'>

# %% [markdown]
# # Comparison operator

# %%
In python comparison operator are used to compare values.These opeartors return True or False based on whether the comaparison is true or false.

# %% [markdown]
# # Equal to ==

# %%
x = 7
y = 5
print(x==y)
# Out:
# False

# %%
m = 2
n = 2
print(m==n)
# Out:
# True

# %% [markdown]
# # not Eqal to !=

# %%
x = 3
y = 7
print(x!=y)
# Out:
# True

# %%
x = 3
y = 3
print(x!=y)
# Out:
# False

# %% [markdown]
# # greater than >

# %%
x = 7
y = 5
print(x>y)
# Out:
# True

# %%
# less than <

# %%
print(56<85)
# Out:
# True

# %%
print(156<85)
# Out:
# False

# %% [markdown]
# # greater than or equal to >=

# %%
x = 6
y = 5
print(x>=y)
# Out:
# True

# %% [markdown]
# # less than or equal to <=

# %%
x = 6
y = 5
print(x<=y)
# Out:
# False

# %% [markdown]
# # Logical operator

# %% [markdown]
# # And operator

# %%
x = True
y = False 
print(x and y)
# Out:
# False

# %%
x = True 
y = False 
print(x or y)
# Out:
# True

# %% [markdown]
# # Not operator

# %%
x = True
print(not x)
# Out:
# False

# %%
x = False 
print(not x)
# Out:
# True

# %% [markdown]
# # Practice Questions

# %% [markdown]
# # Question-1

# %%
We have a data containing two record:"Quantity" and "price per Unit". How would you use arithmetic operators
to calculate the total costs for each items, also calculate the total cost? product 1,Quantity 5,price per
unit-Rs 250 product 2,Quantity 25,price per Unit - Rs 656 product 3,Quantity 34,price per Unit - Rs 274.

# %%
product_1 = 5*250
product_2 = 25*656
product_3 = 34*274
print("Price of product_1 is :Rs",product_1)
print("Price of product_2 is :Rs",product_2)
print("Price of product_3 is :Rs",product_3)
print("The total price customer that need to pay is :Rs",product_1+product_2,product_3)
# Out:
# Price of product_1 is :Rs 1250
# Price of product_2 is :Rs 16400
# Price of product_3 is :Rs 9316
# The total price customer that need to pay is :Rs 17650 9316

# %% [markdown]
# # Question - 2

# %%
In a finance-based organization, the task is to calculate the simple interest given the principal 
amount,interest rate, and time period. The interest rate is 8%, the principal amount is Rs 15,00,000,and
the time period is 3 years. Calculate the simple interest. Also, the thresold amount is Rs 1,20,000.
Please check if the calculated interest is greater or less than the thresold amount.

# %%
P= 1500000
T= 3
R = 8
Thresold =  120000
SI= (P*T*R)//100
print("Simple interest :",SI)
if(SI > Thresold):
    print("Greater")
else:
    print("less")
# Out:
# Simple interest : 360000
# Greater

# %% [markdown]
# # Question - 3

# %%
Write a python program to calculate the area of a circle with a radius of 12 cm.

# %%
r = 12
Area = 3.14*r*r
print("Area of a circle is :",Area)
print(int(Area))
# Out:
# Area of a circle is : 452.15999999999997
# 452
